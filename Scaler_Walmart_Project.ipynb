# %% [markdown]
# <a href="https://colab.research.google.com/github/DrShabirAhmad/Code/blob/main/Scaler_Walmart_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/293/original/walmart_data.csv?1641285094")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
df.shape
# Out:
# (550068, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category  \
# count  5.500680e+05  550068.000000   550068.000000     550068.000000
# mean   1.003029e+06       8.076707        0.409653          5.404270
# std    1.727592e+03       6.522660        0.491770          3.936211
# min    1.000001e+06       0.000000        0.000000          1.000000
# 25%    1.001516e+06       2.000000        0.000000          1.000000
# 50%    1.003077e+06       7.000000        0.000000          5.000000
# 75%    1.004478e+06      14.000000        1.000000          8.000000
# max    1.006040e+06      20.000000        1.000000         20.000000
#
#             Purchase
# count  550068.000000
# mean     9263.968713
# std      5023.065394
# min        12.000000
# 25%      5823.000000
# 50%      8047.000000
# 75%     12054.000000
# max     23961.000000

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # Value Counts & Unique Values

# %%
def distribution(col_name):
  return df[col_name].value_counts()
distribution("Gender")
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
distribution("Marital_Status")
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
distribution("Age")
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
distribution("Occupation")
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
distribution("Product_Category")
# Out:
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: Product_Category, dtype: int64

# %%
distribution("City_Category")
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %%
def Unique_Values(col_name):
  return df[col_name].nunique()
Unique_Values("Gender")
# Out:
# 2

# %%
Unique_Values("Product_Category")
# Out:
# 20

# %%
Unique_Values("Age")
# Out:
# 7

# %%
Unique_Values("Product_ID")
# Out:
# 3631

# %%
Unique_Values("Purchase")
# Out:
# 18105

# %% [markdown]
# # **Graphical Analysis**

# %%
sns.kdeplot(df["Purchase"])
plt.show()

# %%
sns.histplot(df["Purchase"], bins=8)
plt.show()

# %%
sns.scatterplot(data = df, x= "Product_Category", y= "Purchase")
plt.show()

# %%
sns.countplot(data = df, x= "Gender")
plt.show()

# %%
sns.countplot(data = df, x= "Marital_Status")
plt.show()

# %%
sns.countplot(data = df, x= "City_Category")
plt.show()

# %%
sns.countplot(data = df, x= "Age")
plt.show()

# %%
sns.countplot(data = df, x= "Stay_In_Current_City_Years")
plt.show()

# %% [markdown]
# # Box Plots

# %%
sns.boxplot(x="Gender", y= "Purchase", data=df)
plt.show()

# %%
sns.boxplot(x="Gender", y= "Product_Category", data=df)
plt.show()

# %%
sns.boxplot(x="City_Category", y= "Purchase", data=df)
plt.show()

# %%
sns.boxplot(x="Age", y= "Purchase", data=df)
plt.show()

# %% [markdown]
# # Heatmaps, Pairplots

# %%
sns.heatmap(df.corr(), cmap="coolwarm", annot = True)
plt.show()
# Out:
# <ipython-input-102-b52e28152d2b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="coolwarm", annot = True)

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# # Missing value & Outliers

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %%
sns.boxplot(x="Gender", y= "Purchase", data=df)
plt.show()

# %% [markdown]
# # Confidence Intervals

# %%
ample_size_female, sample_size_male = df.groupby("Gender")["Purchase"].count()
sample_size_female, sample_size_male
# Out:
# (135809, 414259)

# %%
df.groupby("Gender")["Purchase"].sum()/df.groupby("Gender")["Purchase"].count()
# Out:
# Gender
# F    8734.565765
# M    9437.526040
# Name: Purchase, dtype: float64

# %%
sample_mean_female, sample_mean_male = round(df.groupby("Gender")["Purchase"].mean(), 2)
sample_mean_female, sample_mean_male
# Out:
# (8734.57, 9437.53)

# %%
gender_median = df.groupby("Gender")["Purchase"].median()
gender_median
# Out:
# Gender
# F    7914.0
# M    8098.0
# Name: Purchase, dtype: float64

# %%
diff_female = (sample_mean_female-gender_median[0])
diff_female
# Out:
# 820.5699999999997

# %%
diff_male = (sample_mean_male-gender_median[1])
diff_male
# Out:
# 1339.5300000000007

# %%
sample_std_female, sample_std_male = round(df.groupby("Gender")["Purchase"].std(), 2)
sample_std_female, sample_std_male
# Out:
# (4767.23, 5092.19)

# %%
CI_Female = round(norm(8734.565765, 4767.233289/np.sqrt(135809)).ppf(0.025), 2), round(norm(8734.565765, 4767.233289/np.sqrt(135809)).ppf(0.975), 2)
CI_Female
# Out:
# (8709.21, 8759.92)

# %%
CI_male = round(norm(9437.526040, 5092.186210/np.sqrt(414259)).ppf(0.025),2), round(norm(9437.526040, 5092.186210/np.sqrt(414259)).ppf(0.975), 2)
CI_male
# Out:
# (9422.02, 9453.03)

# %%
confidence_level = 0.95
Z_score = 1.94
print("Z_score: ", Z_score)

standard_error_female = Z_score *(sample_std_female/np.sqrt(sample_size_female))
standard_error_male = Z_score *(sample_std_male/np.sqrt(sample_size_male))
print("standard_error_female: ", standard_error_female)
print("standard_error_male: ", standard_error_male)

confidence_interval_female = (sample_mean_female - standard_error_female, sample_mean_female + standard_error_female)
confidence_interval_male = (sample_mean_male - standard_error_male, sample_mean_male + standard_error_male)
print("confidence_interval_female: ",confidence_interval_female)
print("confidence_interval_male: ", confidence_interval_male)

if confidence_interval_female == confidence_interval_male:
  print("Since the confidence intervals overlap, therefore there is no difference between the average spending expenses of males and females")
else:
  print("Since the confidence intervals do not overlap, therefore there is significant difference between the average spending expenses of males and females")
# Out:
# Z_score:  1.94
# standard_error_female:  25.095945332954035
# standard_error_male:  15.34865602702587
# confidence_interval_female:  (8709.474054667045, 8759.665945332954)
# confidence_interval_male:  (9422.181343972974, 9452.878656027027)
# Since the confidence intervals do not overlap, therefore there is significant difference between the average spending expenses of males and females

# %%
confidence_level = 0.95
Z_score = norm.ppf((1+confidence_level)/2)
print("Z_score: ", Z_score)

standard_error_female = Z_score *(sample_std_female/np.sqrt(sample_size_female))
standard_error_male = Z_score *(sample_std_male/np.sqrt(sample_size_male))
print("standard_error_female: ", standard_error_female)
print("standard_error_male: ", standard_error_male)

confidence_interval_female = (sample_mean_female - standard_error_female, sample_mean_female + standard_error_female)
confidence_interval_male = (sample_mean_male - standard_error_male, sample_mean_male + standard_error_male)
print("confidence_interval_female: ",confidence_interval_female)
print("confidence_interval_male: ", confidence_interval_male)
# Out:
# Z_score:  1.959963984540054
# standard_error_female:  25.354200520915445
# standard_error_male:  15.506604651579558
# confidence_interval_female:  (8709.215799479085, 8759.924200520914)
# confidence_interval_male:  (9422.02339534842, 9453.036604651581)

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_level = 0.90
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    sample_means = []
    for _ in range(num_samples):
            # Randomly sample 'sample_size' amount spentt for females and calculate the sample mean
      sample = np.random.choice(amount_spent_female, size= sample_size)
      sample_mean = np.mean(sample)
      sample_means.append(sample_mean)

        # Calculate the standard error as std(sample_means)/square root of sample size
    standard_error = (np.std(sample_means) / np.sqrt(sample_size))

        # Calculate the margin of error using the z-score
    z_score = norm.ppf((1 + confidence_level) / 2)
    margin_of_error = z_score * standard_error

        # Calculate the confidence interval as mean +/- margin_of_error
    confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

    results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.9, 'Confidence Interval': (588255311.03, 598999757.79)}
# {'Sample Size': 1000, 'Confidence Level': 0.9, 'Confidence Interval': (592024700.15, 593130327.73)}
# {'Sample Size': 10000, 'Confidence Level': 0.9, 'Confidence Interval': (593072627.32, 593182662.65)}

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_level = 0.95
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    sample_means = []
    for _ in range(num_samples):
            # Randomly sample 'sample_size' amount spentt for females and calculate the sample mean
      sample = np.random.choice(amount_spent_female, size= sample_size)
      sample_mean = np.mean(sample)
      sample_means.append(sample_mean)

        # Calculate the standard error as std(sample_means)/square root of sample size
    standard_error = (np.std(sample_means) / np.sqrt(sample_size))

        # Calculate the margin of error using the z-score
    z_score = 1.94
    margin_of_error = z_score * standard_error

        # Calculate the confidence interval as mean +/- margin_of_error
    confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

    results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.95, 'Confidence Interval': (586457994.96, 599656465.35)}
# {'Sample Size': 1000, 'Confidence Level': 0.95, 'Confidence Interval': (593149238.43, 594477851.19)}
# {'Sample Size': 10000, 'Confidence Level': 0.95, 'Confidence Interval': (593069359.46, 593203990.25)}

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_level = 0.99
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    sample_means = []
    for _ in range(num_samples):
            # Randomly sample 'sample_size' amount spentt for females and calculate the sample mean
      sample = np.random.choice(amount_spent_female, size= sample_size)
      sample_mean = np.mean(sample)
      sample_means.append(sample_mean)

        # Calculate the standard error as std(sample_means)/square root of sample size
    standard_error = (np.std(sample_means) / np.sqrt(sample_size))

        # Calculate the margin of error using the z-score
    z_score = norm.ppf((1 + confidence_level) / 2)
    margin_of_error = z_score * standard_error

        # Calculate the confidence interval as mean +/- margin_of_error
    confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

    results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.99, 'Confidence Interval': (584319734.7, 601788399.31)}
# {'Sample Size': 1000, 'Confidence Level': 0.99, 'Confidence Interval': (592626922.9, 594350328.08)}
# {'Sample Size': 10000, 'Confidence Level': 0.99, 'Confidence Interval': (592975441.4, 593154164.47)}

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_levels = [0.90, 0.95, 0.99]
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    for confidence_level in confidence_levels:
        sample_means = []
        for _ in range(num_samples):
            # Randomly sample 'sample_size' transactions for females and calculate the sample mean
            sample = np.random.choice(amount_spent_female, size= sample_size)
            sample_mean = round(np.mean(sample), 2)
            sample_means.append(sample_mean)

        # Calculate the standard error
        standard_error = np.std(sample_means) / np.sqrt(sample_size)

        # Calculate the margin of error using the z-score
        z_score = norm.ppf((1 + confidence_level) / 2)
        margin_of_error = z_score * standard_error

        # Calculate the confidence interval
        confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

        results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.9, 'Confidence Interval': (585757702.1, 597380583.47)}
# {'Sample Size': 100, 'Confidence Level': 0.95, 'Confidence Interval': (586389769.65, 599719860.01)}
# {'Sample Size': 100, 'Confidence Level': 0.99, 'Confidence Interval': (583657376.46, 600720975.2)}
# {'Sample Size': 1000, 'Confidence Level': 0.9, 'Confidence Interval': (592690215.61, 593832738.18)}
# {'Sample Size': 1000, 'Confidence Level': 0.95, 'Confidence Interval': (592402360.95, 593762027.94)}
# {'Sample Size': 1000, 'Confidence Level': 0.99, 'Confidence Interval': (592324282.26, 594064502.73)}
# {'Sample Size': 10000, 'Confidence Level': 0.9, 'Confidence Interval': (593132543.8, 593244369.36)}
# {'Sample Size': 10000, 'Confidence Level': 0.95, 'Confidence Interval': (592934209.27, 593070979.36)}
# {'Sample Size': 10000, 'Confidence Level': 0.99, 'Confidence Interval': (593259930.61, 593442879.48)}

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_level = 0.99
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    sample_means = []
    for _ in range(num_samples):
            # Randomly sample 'sample_size' amount spentt for females and calculate the sample mean
      sample = np.random.choice(amount_spent_male, size= sample_size)
      sample_mean = np.mean(sample)
      sample_means.append(sample_mean)

        # Calculate the standard error as std(sample_means)/square root of sample size
    standard_error = (np.std(sample_means) / np.sqrt(sample_size))

        # Calculate the margin of error using the z-score
    z_score = norm.ppf((1 + confidence_level) / 2)
    margin_of_error = z_score * standard_error

        # Calculate the confidence interval as mean +/- margin_of_error
    confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

    results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.99, 'Confidence Interval': (1931423467.74, 1987260435.67)}
# {'Sample Size': 1000, 'Confidence Level': 0.99, 'Confidence Interval': (1951863313.43, 1957652589.73)}
# {'Sample Size': 10000, 'Confidence Level': 0.99, 'Confidence Interval': (1954519753.06, 1955103941.21)}

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_level = 0.95
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    sample_means = []
    for _ in range(num_samples):
            # Randomly sample 'sample_size' amount spentt for females and calculate the sample mean
      sample = np.random.choice(amount_spent_male, size= sample_size)
      sample_mean = np.mean(sample)
      sample_means.append(sample_mean)

        # Calculate the standard error as std(sample_means)/square root of sample size
    standard_error = (np.std(sample_means) / np.sqrt(sample_size))

        # Calculate the margin of error using the z-score
    z_score = norm.ppf((1 + confidence_level) / 2)
    margin_of_error = z_score * standard_error

        # Calculate the confidence interval as mean +/- margin_of_error
    confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

    results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.95, 'Confidence Interval': (1929504050.13, 1973411121.11)}
# {'Sample Size': 1000, 'Confidence Level': 0.95, 'Confidence Interval': (1952917563.82, 1957406665.2)}
# {'Sample Size': 10000, 'Confidence Level': 0.95, 'Confidence Interval': (1954137993.91, 1954589000.38)}

# %%
# Define sample size, confidence levels, and number of samples
sample_sizes = [100, 1000, 10000]
confidence_levels = [0.90, 0.95, 0.99]
num_samples = 1000

# Initialize lists to store results
results = []

for sample_size in sample_sizes:
    for confidence_level in confidence_levels:
        sample_means = []
        for _ in range(num_samples):
            # Randomly sample 'sample_size' transactions for females and calculate the sample mean
            sample = np.random.choice(amount_spent_female, size= sample_size)
            sample_mean = round(np.mean(sample), 2)
            sample_means.append(sample_mean)

        # Calculate the standard error
        standard_error = np.std(sample_means) / np.sqrt(sample_size)

        # Calculate the margin of error using the z-score
        z_score = norm.ppf((1 + confidence_level) / 2)
        margin_of_error = z_score * standard_error

        # Calculate the confidence interval
        confidence_interval = (round(np.mean(sample_means) - margin_of_error, 2), round(np.mean(sample_means) + margin_of_error, 2))

        results.append({
            'Sample Size': sample_size,
            'Confidence Level': confidence_level,
            'Confidence Interval': confidence_interval
        })

# Print or analyze the results
for result in results:
    print(result)
# Out:
# {'Sample Size': 100, 'Confidence Level': 0.9, 'Confidence Interval': (586790294.38, 598154416.57)}
# {'Sample Size': 100, 'Confidence Level': 0.95, 'Confidence Interval': (587234545.83, 600647184.62)}
# {'Sample Size': 100, 'Confidence Level': 0.99, 'Confidence Interval': (585873285.65, 603132420.46)}
# {'Sample Size': 1000, 'Confidence Level': 0.9, 'Confidence Interval': (592924998.99, 594111919.02)}
# {'Sample Size': 1000, 'Confidence Level': 0.95, 'Confidence Interval': (593324648.83, 594612759.79)}
# {'Sample Size': 1000, 'Confidence Level': 0.99, 'Confidence Interval': (591820309.53, 593546443.69)}
# {'Sample Size': 10000, 'Confidence Level': 0.9, 'Confidence Interval': (592945984.55, 593059851.35)}
# {'Sample Size': 10000, 'Confidence Level': 0.95, 'Confidence Interval': (593123461.28, 593259414.62)}
# {'Sample Size': 10000, 'Confidence Level': 0.99, 'Confidence Interval': (593039664.36, 593214370.07)}

# %%
amount_spent_married, amount_spent_unmarried = df.groupby("Marital_Status")["Purchase"].sum()
amount_spent_married, amount_spent_unmarried
# Out:
# (3008927447, 2086885295)

# %%
sample_size_married, sample_size_unmarried = df.groupby("Marital_Status")["Purchase"].count()
sample_size_married, sample_size_unmarried
# Out:
# (324731, 225337)

# %%
sample_mean_married, sample_mean_unmarried = round(df.groupby("Marital_Status")["Purchase"].mean(), 2)
sample_mean_married, sample_mean_unmarried
# Out:
# (9265.91, 9261.17)

# %%
sample_std_married, sample_std_unmarried = round(df.groupby("Marital_Status")["Purchase"].std(), 2)
sample_std_married, sample_std_unmarried
# Out:
# (5027.35, 5016.9)

# %%
CI_married = round(norm(sample_mean_married, sample_std_married/np.sqrt(sample_size_married)).ppf(0.025), 2), round(norm(sample_mean_married, sample_std_married/np.sqrt(sample_size_married)).ppf(.975), 2)
CI_married
# Out:
# (9248.62, 9283.2)

# %%
CI_unmarried = round(norm(sample_mean_unmarried, sample_std_unmarried/np.sqrt(sample_size_unmarried)).ppf(0.025), 2), round(norm(sample_mean_unmarried, sample_std_unmarried/np.sqrt(sample_size_unmarried)).ppf(.975), 2)
CI_unmarried
# Out:
# (9240.46, 9281.88)

# %%
confidence_level = 0.95
Z_score = 1.94
print("Z_score: ", Z_score)

standard_error_married = Z_score *(sample_std_married/np.sqrt(sample_size_married))
standard_error_unmarried = Z_score *(sample_std_unmarried/np.sqrt(sample_size_unmarried))
print("standard_error_married: ", standard_error_married)
print("standard_error_unmarried: ", standard_error_unmarried)

confidence_interval_married = (sample_mean_married - standard_error_married, sample_mean_married + standard_error_married)
confidence_interval_unmarried = (sample_mean_unmarried - standard_error_unmarried, sample_mean_unmarried + standard_error_unmarried)
print("confidence_interval_married: ",confidence_interval_married)
print("confidence_interval_unmarried: ", confidence_interval_unmarried)

if (confidence_interval_married) > (confidence_interval_unmarried):
  print("Since the confidence intervals overlap, therefore there is no difference between the average spending expenses of married and unmarried")
else:
  print("Since the confidence intervals do not overlap, therefore there is significant difference between the average spending expenses of married and unmarried")
# Out:
# Z_score:  1.94
# standard_error_married:  17.11508169442643
# standard_error_unmarried:  20.503165644868236
# confidence_interval_married:  (9248.794918305573, 9283.025081694426)
# confidence_interval_unmarried:  (9240.666834355132, 9281.673165644868)
# Since the confidence intervals overlap, therefore there is no difference between the average spending expenses of married and unmarried

# %%
df["Age"].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
grp1= df[df["Age"]=="0-17"]
grp2= df[df["Age"]=="18-25"]
grp3= df[df["Age"]=="26-35"]
grp4= df[df["Age"]=="36-45"]
grp5= df[df["Age"]=="46-50"]
grp6= df[df["Age"]=="51-55"]
grp7= df[df["Age"]=="55+"]

# %%
amount_spent_grp1, amount_spent_grp2, amount_spent_grp3, amount_spent_grp4, amount_spent_grp5, amount_spent_grp6, amount_spent_grp7 = df.groupby("Age")["Purchase"].sum()
amount_spent_grp1, amount_spent_grp2, amount_spent_grp3, amount_spent_grp4, amount_spent_grp5, amount_spent_grp6, amount_spent_grp7
# Out:
# (134913183, 913848675, 2031770578, 1026569884, 420843403, 367099644, 200767375)

# %%
sample_size_grp1, sample_size_grp2, sample_size_grp3, sample_size_grp4, sample_size_grp5, sample_size_grp6, sample_size_grp7 = df.groupby("Age")["Purchase"].count()
sample_size_grp1, sample_size_grp2, sample_size_grp3, sample_size_grp4, sample_size_grp5, sample_size_grp6, sample_size_grp7
# Out:
# (15102, 99660, 219587, 110013, 45701, 38501, 21504)

# %%
sample_mean_grp1, sample_mean_grp2, sample_mean_grp3, sample_mean_grp4, sample_mean_grp5, sample_mean_grp6, sample_mean_grp7 = round(df.groupby("Age")["Purchase"].mean(), 2)
sample_mean_grp1, sample_mean_grp2, sample_mean_grp3, sample_mean_grp4, sample_mean_grp5, sample_mean_grp6, sample_mean_grp7
# Out:
# (8933.46, 9169.66, 9252.69, 9331.35, 9208.63, 9534.81, 9336.28)

# %%
sample_std_grp1, sample_std_grp2, sample_std_grp3, sample_std_grp4, sample_std_grp5, sample_std_grp6, sample_std_grp7 = round(df.groupby("Age")["Purchase"].std(), 2)
sample_std_grp1, sample_std_grp2, sample_std_grp3, sample_std_grp4, sample_std_grp5, sample_std_grp6, sample_std_grp7
# Out:
# (5111.11, 5034.32, 5010.53, 5022.92, 4967.22, 5087.37, 5011.49)

# %%
confidence_level = 0.95
Z_score = 1.94
print("Z_score: ", Z_score)

standard_error_grp1 = Z_score *(sample_std_grp1/np.sqrt(sample_size_grp1))
standard_error_grp2 = Z_score *(sample_std_grp2/np.sqrt(sample_size_grp2))
standard_error_grp3 = Z_score *(sample_std_grp3/np.sqrt(sample_size_grp3))
standard_error_grp4 = Z_score *(sample_std_grp4/np.sqrt(sample_size_grp4))
standard_error_grp5 = Z_score *(sample_std_grp5/np.sqrt(sample_size_grp5))
standard_error_grp6 = Z_score *(sample_std_grp6/np.sqrt(sample_size_grp6))
standard_error_grp7 = Z_score *(sample_std_grp7/np.sqrt(sample_size_grp7))

print("standard_error_grp1: ", standard_error_grp1)
print("standard_error_grp2: ", standard_error_grp2)
print("standard_error_grp3: ", standard_error_grp3)
print("standard_error_grp4: ", standard_error_grp4)
print("standard_error_grp5: ", standard_error_grp5)
print("standard_error_grp6: ", standard_error_grp6)
print("standard_error_grp7: ", standard_error_grp7)

confidence_interval_grp1 = (sample_mean_grp1 - standard_error_grp1, sample_mean_grp1 + standard_error_grp1)
confidence_interval_grp2 = (sample_mean_grp2 - standard_error_grp2, sample_mean_grp2 + standard_error_grp2)
confidence_interval_grp3 = (sample_mean_grp3 - standard_error_grp3, sample_mean_grp3 + standard_error_grp3)
confidence_interval_grp4 = (sample_mean_grp4 - standard_error_grp4, sample_mean_grp4 + standard_error_grp4)
confidence_interval_grp5 = (sample_mean_grp5 - standard_error_grp5, sample_mean_grp5 + standard_error_grp5)
confidence_interval_grp6 = (sample_mean_grp6 - standard_error_grp6, sample_mean_grp6 + standard_error_grp6)
confidence_interval_grp7 = (sample_mean_grp7 - standard_error_grp7, sample_mean_grp7 + standard_error_grp7)


print("confidence_interval_grp1: ",confidence_interval_grp1)
print("confidence_interval_grp2: ",confidence_interval_grp2)
print("confidence_interval_grp3: ",confidence_interval_grp3)
print("confidence_interval_grp4: ",confidence_interval_grp4)
print("confidence_interval_grp5: ",confidence_interval_grp5)
print("confidence_interval_grp6: ",confidence_interval_grp6)
print("confidence_interval_grp7: ",confidence_interval_grp7)


if (confidence_interval_grp1) != (confidence_interval_grp2):
  print("Since the confidence intervals do not overlap, therefore there is significant difference between the average spending expenses of different age groups")
else:
  print("Since the confidence intervals overlap, therefore there is no significant difference between the average spending expenses different age groups")
# Out:
# Z_score:  1.94
# standard_error_grp1:  80.6862859067726
# standard_error_grp2:  30.937278433933745
# standard_error_grp3:  20.743502307304034
# standard_error_grp4:  29.378930863942713
# standard_error_grp5:  45.07671654282882
# standard_error_grp6:  50.29896511762674
# standard_error_grp7:  66.29930446853814
# confidence_interval_grp1:  (8852.773714093226, 9014.146285906772)
# confidence_interval_grp2:  (9138.722721566066, 9200.597278433934)
# confidence_interval_grp3:  (9231.946497692696, 9273.433502307305)
# confidence_interval_grp4:  (9301.971069136058, 9360.728930863943)
# confidence_interval_grp5:  (9163.55328345717, 9253.706716542829)
# confidence_interval_grp6:  (9484.511034882373, 9585.108965117626)
# confidence_interval_grp7:  (9269.980695531463, 9402.579304468538)
# Since the confidence intervals do not overlap, therefore there is significant difference between the average spending expenses of different age groups

# %%
# Prepared by: Dr. Shabir AHmad Dar
#####          DSML Nov 2023 Batch
